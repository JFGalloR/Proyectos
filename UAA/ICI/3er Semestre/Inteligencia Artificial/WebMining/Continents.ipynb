# %%
def get_continent_by_country_name(country_name):
    country_continent_mapping = {
        "Afghanistan": "Asia",
        "Albania": "Europa",
        "Algeria": "África",
        "Andorra": "Europa",
        "Angola": "África",
        "Antigua and Barbuda": "América del Norte",
        "Argentina": "América del Sur",
        "Armenia": "Asia",
        "Australia": "Oceanía",
        "Austria": "Europa",
        "Azerbaijan": "Asia",
        "Bahamas": "América del Norte",
        "Bahrain": "Asia",
        "Bangladesh": "Asia",
        "Barbados": "América del Norte",
        "Belarus": "Europa",
        "Belgium": "Europa",
        "Belize": "América del Norte",
        "Benin": "África",
        "Bhutan": "Asia",
        "Bolivia": "América del Sur",
        "Bosnia and Herzegovina": "Europa",
        "Botswana": "África",
        "Brazil": "América del Sur",
        "Brunei": "Asia",
        "Bulgaria": "Europa",
        "Burkina Faso": "África",
        "Burundi": "África",
        "Cambodia": "Asia",
        "Cameroon": "África",
        "Canada": "América del Norte",
        "Cape Verde": "África",
        "Central African Republic": "África",
        "Chad": "África",
        "Chile": "América del Sur",
        "China": "Asia",
        "Colombia": "América del Sur",
        "Comoros": "África",
        "Costa Rica": "América del Norte",
        "Croatia": "Europa",
        "Cuba": "América del Norte",
        "Cyprus": "Europa",
        "Czech Republic": "Europa",
        "Democratic Republic of the Congo": "África",
        "Denmark": "Europa",
        "Djibouti": "África",
        "Dominica": "América del Norte",
        "Dominican Republic": "América del Norte",
        "East Timor": "Asia",
        "Ecuador": "América del Sur",
        "Egypt": "África",
        "El Salvador": "América del Norte",
        "Equatorial Guinea": "África",
        "Eritrea": "África",
        "Estonia": "Europa",
        "Eswatini": "África",
        "Ethiopia": "África",
        "Fiji": "Oceanía",
        "Finland": "Europa",
        "France": "Europa",
        "Gabon": "África",
        "Gambia": "África",
        "Georgia": "Asia",
        "Germany": "Europa",
        "Ghana": "África",
        "Greece": "Europa",
        "Grenada": "América del Norte",
        "Guatemala": "América del Norte",
        "Guinea": "África",
        "Guinea-Bissau": "África",
        "Guyana": "América del Sur",
        "Haiti": "América del Norte",
        "Honduras": "América del Norte",
        "Hungary": "Europa",
        "Iceland": "Europa",
        "India": "Asia",
        "Indonesia": "Asia",
        "Iran": "Asia",
        "Iraq": "Asia",
        "Ireland": "Europa",
        "Israel": "Asia",
        "Italy": "Europa",
        "Ivory Coast": "África",
        "Jamaica": "América del Norte",
        "Japan": "Asia",
        "Jordan": "Asia",
        "Kazakhstan": "Asia",
        "Kenya": "África",
        "Kiribati": "Oceanía",
        "Kuwait": "Asia",
        "Kyrgyzstan": "Asia",
        "Laos": "Asia",
        "Latvia": "Europa",
        "Lebanon": "Asia",
        "Lesotho": "África",
        "Liberia": "África",
        "Libya": "África",
        "Liechtenstein": "Europa",
        "Lithuania": "Europa",
        "Luxembourg": "Europa",
        "Madagascar": "África",
        "Malawi": "África",
        "Malaysia": "Asia",
        "Maldives": "Asia",
        "Mali": "África",
        "Malta": "Europa",
        "Marshall Islands": "Oceanía",
        "Mauritania": "África",
        "Mauritius": "África",
        "Mexico": "América del Norte",
        "Micronesia": "Oceanía",
        "Moldova": "Europa",
        "Monaco": "Europa",
        "Mongolia": "Asia",
        "Montenegro": "Europa",
        "Morocco": "África",
        "Mozambique": "África",
        "Myanmar": "Asia",
        "Namibia": "África",
        "Nauru": "Oceanía",
        "Nepal": "Asia",
        "Netherlands": "Europa",
        "New Zealand": "Oceanía",
        "Nicaragua": "América del Norte",
        "Niger": "África",
        "Nigeria": "África",
        "North Macedonia": "Europa",
        "Norway": "Europa",
        "Oman": "Asia",
        "Pakistan": "Asia",
        "Palau": "Oceanía",
        "Panama": "América del Norte",
        "Papua New Guinea": "Oceanía",
        "Paraguay": "América del Sur",
        "Peru": "América del Sur",
        "Philippines": "Asia",
        "Poland": "Europa",
        "Portugal": "Europa",
        "Qatar": "Asia",
        "Republic of the Congo": "África",
        "Romania": "Europa",
        "Russia": "Europa/Asia",
        "Rwanda": "África",
        "Saint Kitts and Nevis": "América del Norte",
        "Saint Lucia": "América del Norte",
        "Saint Vincent and the Grenadines": "América del Norte",
        "Samoa": "Oceanía",
        "San Marino": "Europa",
        "Sao Tome and Principe": "África",
        "Saudi Arabia": "Asia",
        "Senegal": "África",
        "Serbia": "Europa",
        "Seychelles": "África",
        "Sierra Leone": "África",
        "Singapore": "Asia",
        "Slovakia": "Europa",
        "Slovenia": "Europa",
        "Solomon Islands": "Oceanía",
        "Somalia": "África",
        "South Africa": "África",
        "South Korea": "Asia",
        "South Sudan": "África",
        "Spain": "Europa",
        "Sri Lanka": "Asia",
        "Sudan": "África",
        "Suriname": "América del Sur",
        "Sweden": "Europa",
        "Switzerland": "Europa",
        "Syria": "Asia",
        "Tajikistan": "Asia",
        "Tanzania": "África",
        "Thailand": "Asia",
        "Togo": "África",
        "Tonga": "Oceanía",
        "Trinidad and Tobago": "América del Norte",
        "Tunisia": "África",
        "Turkey": "Asia/Europa",
        "Turkmenistan": "Asia",
        "Tuvalu": "Oceanía",
        "Uganda": "África",
        "Ukraine": "Europa",
        "United Arab Emirates": "Asia",
        "United Kingdom": "Europa",
        "United States": "América del Norte",
        "Uruguay": "América del Sur",
        "Uzbekistan": "Asia",
        "Vanuatu": "Oceanía",
        "Vatican City": "Europa",
        "Venezuela": "América del Sur",
        "Vietnam": "Asia",
        "Yemen": "Asia",
        "Zambia": "África",
        "Zimbabwe": "África",
        # Puedes seguir agregando más países y continentes aquí
    }

    return country_continent_mapping.get(country_name, "Desconocido")
